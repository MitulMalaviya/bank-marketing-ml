# %% [markdown]
# <pre>
# <center><b><h1>Bank Marketing Campaign</b></center>
# <center><b><h1>EDA</b></center>
# <center><b>Name : Mehta Sneha</b></center>
# <center><b>Roll number : 455</b></center>
# <pre>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Assign dataset to a variable called df

# %%
df = pd.read_csv("bank-full.csv",sep=";")
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ### Step 3. See the first 10 entries

# %%
df.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %% [markdown]
# ### Step 4. See the last 10 entries

# %%
df.tail(10)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45201   53    management   married   tertiary      no      583      no   no
# 45202   34        admin.    single  secondary      no      557      no   no
# 45203   23       student    single   tertiary      no      113      no   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
df.shape  #for total number of row and columns
# Out:
# (45211, 17)

# %%
print('Rows:', df.shape[0], '| Columns:', df.shape[1])
# Out:
# Rows: 45211 | Columns: 17

# %% [markdown]
# ### Step 6. Print the name of all the columns.

# %%
df.columns.tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %% [markdown]
# ### Step 7. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45211, step=1)

# %% [markdown]
# ### Step 8. What is the data type of each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# ### Step 9. Missing values

# %%
print(df.isnull().sum())
print('Total missing:', df.isnull().sum().sum())
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
# Total missing: 0

# %% [markdown]
# ### Step 10. Average age of clients

# %%
print('Average age:', df['age'].mean())
# Out:
# Average age: 40.93621021432837

# %% [markdown]
# ### Step 11. Job type distribution

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %% [markdown]
# ### Step 12. Min/Max bank balance

# %%
print('Min balance:', df['balance'].min(), '| Max balance:', df['balance'].max())
# Out:
# Min balance: -8019 | Max balance: 102127

# %% [markdown]
# ### Step 13. Education Analysis

# %%
df.groupby('education')['y'].value_counts()
# Out:
# education  y
# primary    no      6260
#            yes      591
# secondary  no     20752
#            yes     2450
# tertiary   no     11305
#            yes     1996
# unknown    no      1605
#            yes      252
# Name: count, dtype: int64

# %% [markdown]
# ### Step 14. Marital Status Analysis

# %%
df.groupby('marital')['y'].value_counts()
# Out:
# marital   y
# divorced  no      4585
#           yes      622
# married   no     24459
#           yes     2755
# single    no     10878
#           yes     1912
# Name: count, dtype: int64

# %% [markdown]
# ### Step 15. Contact Method Analysis

# %%
df.groupby('contact')['y'].value_counts()
# Out:
# contact    y
# cellular   no     24916
#            yes     4369
# telephone  no      2516
#            yes      390
# unknown    no     12490
#            yes      530
# Name: count, dtype: int64

# %% [markdown]
# ### Step 16. Previous Campaign Success

# %%
df.groupby('poutcome')['y'].value_counts()
# Out:
# poutcome  y
# failure   no      4283
#           yes      618
# other     no      1533
#           yes      307
# success   yes      978
#           no       533
# unknown   no     33573
#           yes     3386
# Name: count, dtype: int64

# %% [markdown]
# ### Step 17. Best Month for Marketing

# %%
df.groupby('month')['y'].value_counts()
# Out:
# month  y
# apr    no      2355
#        yes      577
# aug    no      5559
#        yes      688
# dec    no       114
#        yes      100
# feb    no      2208
#        yes      441
# jan    no      1261
#        yes      142
# jul    no      6268
#        yes      627
# jun    no      4795
#        yes      546
# mar    yes      248
#        no       229
# may    no     12841
#        yes      925
# nov    no      3567
#        yes      403
# oct    no       415
#        yes      323
# sep    no       310
#        yes      269
# Name: count, dtype: int64

# %% [markdown]
# ### Step 18. Summarize the DataFrame.

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ### Step 19. Average balance by education level

# %%
avg_balance_edu = df.groupby('education')['balance'].mean()
print(avg_balance_edu)
# Out:
# education
# primary      1250.949934
# secondary    1154.880786
# tertiary     1758.416435
# unknown      1526.754443
# Name: balance, dtype: float64

# %% [markdown]
# ### Step 20.Top 3 months with the highest number of contacts

# %%
print("Top 3 most contacted months:")
print(df['month'].value_counts().head(3))
# Out:
# Top 3 most contacted months:
# month
# may    13766
# jul     6895
# aug     6247
# Name: count, dtype: int64

# %% [markdown]
# ### Step 21.Total clients who have both a housing loan and a personal loan

# %%
both_loans = df[(df['housing'] == 'yes') & (df['loan'] == 'yes')].shape[0]
print('Clients with both housing and personal loans:', both_loans)
# Out:
# Clients with both housing and personal loans: 4367

# %% [markdown]
# ### 1. Histogram (Age Distribution)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

df['age'].hist()
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 2. Box Plot (Balance Outliers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('bank-full.csv', sep=';')

sns.boxplot(x=df['balance'])
plt.title('Balance Box Plot')
plt.show()

# %% [markdown]
# ### 3. Scatter Plot (Age vs Balance)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

plt.scatter(df['age'], df['balance'])
plt.xlabel('Age')
plt.ylabel('Balance')
plt.title('Age vs Balance')
plt.show()

# %% [markdown]
# ### 4. Bar Chart (Job Distribution)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

df['job'].value_counts().plot(kind='bar')
plt.title('Job Distribution')
plt.xlabel('Job')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 5. Pie Chart (Marital Status)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

df['marital'].value_counts().plot(
    kind='pie'
)
plt.title('Marital Status')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 6. Count Plot (Education)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

sns.countplot(x='education', data=df)
plt.title('Education Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Count Plot (Target Variable y)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('bank-full.csv', sep=';')

sns.countplot(x='y', data=df)
plt.title('Term Deposit Subscription')
plt.show()

# %%
df.dropna(inplace = True)

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['balance'] = df['balance'].fillna(df['balance'].median())

# %%
df['job'] = df['job'].fillna(df['job'].mode()[0])

# %%
df.ffill(inplace=True)

# %%
print(df.head())
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load dataset
df = pd.read_csv('bank-full.csv', sep=';')

# Check original data types
print("Before Conversion:")
print(df.dtypes)

# Create LabelEncoder
le = LabelEncoder()

# Convert all object/categorical columns to numeric
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])

# Check data after conversion
print("\nAfter Conversion:")
print(df.head())

# Check data types
print("\nData Types:")
print(df.dtypes)
# Out:
# Before Conversion:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object
#
# After Conversion:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['age','balance']] = scaler.fit_transform(df[['age','balance']])
df
# Out:
#             age  job  marital  education  default   balance  housing  loan  \
# 0      0.519481    4        1          2        0  0.092259        1     0
# 1      0.337662    9        2          1        0  0.073067        1     0
# 2      0.194805    2        1          1        0  0.072822        1     1
# 3      0.376623    1        1          3        0  0.086476        1     0
# 4      0.194805   11        2          3        0  0.072812        0     0
# ...         ...  ...      ...        ...      ...       ...      ...   ...
# 45206  0.428571    9        1          2        0  0.080293        0     0
# 45207  0.688312    5        0          0        0  0.088501        0     0
# 45208  0.701299    5        1          1        0  0.124689        0     0
# 45209  0.506494    1        1          1        0  0.078868        0     0
# 45210  0.246753    2        1          1        0  0.099777        0     0
#
# ...
